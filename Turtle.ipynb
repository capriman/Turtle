# %%
#Stary night Turtle


import turtle
import random

#window making

win=turtle.Screen()
win.setup(width=800, height=600)
win.bgcolor('black')

colors=['red','blue','orange','yellow','magenta','purple','peru','ivory']

#lets get a moon

moon=turtle.Turtle()
moon.hideturtle()


#lets get Stars

star=turtle.Turtle()
star.speed(0)
star.hideturtle()


#lets get Texts

text=turtle.Turtle()
text.speed(5)
text.hideturtle()


#function for moon
def draw_moon(pos,color):
    x,y= pos
    moon.color(color)
    moon.penup()
    moon.goto(x,y)
    moon.pendown()
    moon.begin_fill()
    moon.circle(50)
    moon.end_fill()
    
#draw_moon((-300,170),'white')

#it's been a full circle moon. bur we want a half circle moon

#draw_moon((-278,183),'black')


#now function for star

def draw_star(pos,color,length): 
    x,y= pos
    star.color(color)
    star.penup()
    star.goto(x,y)
    star.pendown()
    star.begin_fill()
    for i in range(5):
        star.forward(length)
        star.right(144)
        star.forward(length)
    star.end_fill()

#draw_star((100,100),'red',25)

#now function for the text

def write_text(color):
    text.color(color)
    text.penup()
    text.goto(-370,-270)
    text.pendown()
    style=('Stencil Std Bold',50)
    text.write('Good nighT from amaN...',font=style,move=True)
#write_text('green')

#ok now make things random

def random_pos():
    return(random.randint(-390,390),random.randint(-200,290))

def random_length():
    return(random.randint(5,25))
    
    
    
draw_moon((-300,170),'white')
draw_moon((-278,183),'black')    
    
while True:
    color=random.choice(colors)
    pos=random_pos()
    length=random_length()

    draw_star(pos,color,length)
    write_text(color)
    
    
turtle.done()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# <ipython-input-1-4c2dfb91ed5e> in <module>
#      98
#      99     draw_star(pos,color,length)
# --> 100     write_text(color)
#     101
#     102
#
# <ipython-input-1-4c2dfb91ed5e> in write_text(color)
#      76     text.pendown()
#      77     style=('Stencil Std Bold',50)
# ---> 78     text.write('Good nighT from amaN...',font=style,move=True)
#      79 #write_text('green')
#      80
#
# ~\anaconda3\lib\turtle.py in write(self, arg, move, align, font)
#    3432         if move:
#    3433             x, y = self.pos()
# -> 3434             self.setpos(end, y)
#    3435         if self.undobuffer:
#    3436             self.undobuffer.cumulate = False
#
# ~\anaconda3\lib\turtle.py in goto(self, x, y)
#    1774             self._goto(Vec2D(*x))
#    1775         else:
# -> 1776             self._goto(Vec2D(x, y))
#    1777
#    1778     def home(self):
#
# ~\anaconda3\lib\turtle.py in _goto(self, end)
#    3174                 self._position = start + delta * n
#    3175                 if self._drawing:
# -> 3176                     screen._drawline(self.drawingLineItem,
#    3177                                      (start, self._position),
#    3178                                      self._pencolor, self._pensize, top)
#
# ~\anaconda3\lib\turtle.py in _drawline(self, lineitem, coordlist, fill, width, top)
#     543                 cl.append(x * self.xscale)
#     544                 cl.append(-y * self.yscale)
# --> 545             self.cv.coords(lineitem, *cl)
#     546         if fill is not None:
#     547             self.cv.itemconfigure(lineitem, fill=fill)
#
# <string> in coords(self, *args, **kw)
#
# ~\anaconda3\lib\tkinter\__init__.py in coords(self, *args)
#    2759         return [self.tk.getdouble(x) for x in
#    2760                            self.tk.splitlist(
# -> 2761                    self.tk.call((self._w, 'coords') + args))]
#    2762
#    2763     def _create(self, itemType, args, kw): # Args: (val, val, ..., cnf={})
#
# TclError: invalid command name ".!canvas"

# %%
import turtle
color=['red','blue','green']

turtle.speed (0)

turtle.pencolor('color')
for i in range (100):
    turtle.forward(200)
    turtle.left(125)
    
turtle.pencolor(color)
for i in range(100):
    turtle.forward(250)
    turtle.left(200)
turtle.done()
# Out:
# ---------------------------------------------------------------------------
# TurtleGraphicsError                       Traceback (most recent call last)
# <ipython-input-1-0b38d06525a2> in <module>
#       4 turtle.speed (0)
#       5
# ----> 6 turtle.pencolor('color')
#       7 for i in range (100):
#       8     turtle.forward(200)
#
# ~\anaconda3\lib\turtle.py in pencolor(*args)
#
# ~\anaconda3\lib\turtle.py in pencolor(self, *args)
#    2250         """
#    2251         if args:
# -> 2252             color = self._colorstr(args)
#    2253             if color == self._pencolor:
#    2254                 return
#
# ~\anaconda3\lib\turtle.py in _colorstr(self, args)
#    2694
#    2695     def _colorstr(self, args):
# -> 2696         return self.screen._colorstr(args)
#    2697
#    2698     def _cc(self, args):
#
# ~\anaconda3\lib\turtle.py in _colorstr(self, color)
#    1156                 return color
#    1157             else:
# -> 1158                 raise TurtleGraphicsError("bad color string: %s" % str(color))
#    1159         try:
#    1160             r, g, b = color
#
# TurtleGraphicsError: bad color string: color

# %%
import turtle

shape("arrow")
wheel=12
bgcolor("green")
pensize(5)
pencolor("red")
speed(5)
for i in range(wheel):
    begin_fill()
    rt(90)
    fd(200)
    lt(120)
    fd(200)
    lt(120)
    fd(200)
    end_fill()
    fd(200)
    
turtle.done()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-276278f23ba8> in <module>
#       1 import turtle
#       2
# ----> 3 shape("arrow")
#       4 wheel=12
#       5 bgcolor("green")
#
# NameError: name 'shape' is not defined

# %%
import turtle
turtle.color("red","yellow")
turtle.begin_fill()

for i in range(50):
    turtle.forward(300)
    turtle.left(170)

turtle.end_fill()
turtle.done()

# %%
import turtle
import math
import random

bob = turtle.Turtle()
turtle.colormode(255)
bob.speed(10)

for i in range(2000):
    bob.forward(math.sqrt(i))
    bob.left(i%180)

turtle.done()

# %%
import turtle

a=turtle.Turtle()

a.color("green", "blue")
a.speed(5)
a.begin_fill()

for i in range (50):
    a.forward(100)
    a.left(130)
a.end_fill()
turtle.done()
# Out:
# ---------------------------------------------------------------------------
# Terminator                                Traceback (most recent call last)
# <ipython-input-2-09c9fcc62037> in <module>
#       1 import turtle
#       2
# ----> 3 a=turtle.Turtle()
#       4
#       5 a.color("green", "blue")
#
# ~\anaconda3\lib\turtle.py in __init__(self, shape, undobuffersize, visible)
#    3811         if Turtle._screen is None:
#    3812             Turtle._screen = Screen()
# -> 3813         RawTurtle.__init__(self, Turtle._screen,
#    3814                            shape=shape,
#    3815                            undobuffersize=undobuffersize,
#
# ~\anaconda3\lib\turtle.py in __init__(self, canvas, shape, undobuffersize, visible)
#    2555         self._undobuffersize = undobuffersize
#    2556         self.undobuffer = Tbuffer(undobuffersize)
# -> 2557         self._update()
#    2558
#    2559     def reset(self):
#
# ~\anaconda3\lib\turtle.py in _update(self)
#    2658             return
#    2659         elif screen._tracing == 1:
# -> 2660             self._update_data()
#    2661             self._drawturtle()
#    2662             screen._update()                  # TurtleScreenBase
#
# ~\anaconda3\lib\turtle.py in _update_data(self)
#    2644
#    2645     def _update_data(self):
# -> 2646         self.screen._incrementudc()
#    2647         if self.screen._updatecounter != 0:
#    2648             return
#
# ~\anaconda3\lib\turtle.py in _incrementudc(self)
#    1290         if not TurtleScreen._RUNNING:
#    1291             TurtleScreen._RUNNING = True
# -> 1292             raise Terminator
#    1293         if self._tracing > 0:
#    1294             self._updatecounter += 1
#
# Terminator:

# %%
import turtle
from random import randint

t1 = turtle.Turtle()

t1.shape('turtle')
t1.penup()
#t1.goto(randint(-100,0),randint(0,100))
t1.pendown()
for i in range (50):
    t1.goto(randint(-100,0),randint(0,100))
    t1.forward(10)
    t1.left(90)
    
turtle.exitonclick()
# Out:
# ---------------------------------------------------------------------------
# Terminator                                Traceback (most recent call last)
# <ipython-input-2-3bafb59b200f> in <module>
#      11     t1.goto(randint(-100,0),randint(0,100))
#      12     t1.forward(10)
# ---> 13     t1.left(90)
#      14
#      15 turtle.exitonclick()
#
# ~\anaconda3\lib\turtle.py in left(self, angle)
#    1697         67.0
#    1698         """
# -> 1699         self._rotate(angle)
#    1700
#    1701     def pos(self):
#
# ~\anaconda3\lib\turtle.py in _rotate(self, angle)
#    3274             for _ in range(steps):
#    3275                 self._orient = self._orient.rotate(delta)
# -> 3276                 self._update()
#    3277         self._orient = neworient
#    3278         self._update()
#
# ~\anaconda3\lib\turtle.py in _update(self)
#    2658             return
#    2659         elif screen._tracing == 1:
# -> 2660             self._update_data()
#    2661             self._drawturtle()
#    2662             screen._update()                  # TurtleScreenBase
#
# ~\anaconda3\lib\turtle.py in _update_data(self)
#    2644
#    2645     def _update_data(self):
# -> 2646         self.screen._incrementudc()
#    2647         if self.screen._updatecounter != 0:
#    2648             return
#
# ~\anaconda3\lib\turtle.py in _incrementudc(self)
#    1290         if not TurtleScreen._RUNNING:
#    1291             TurtleScreen._RUNNING = True
# -> 1292             raise Terminator
#    1293         if self._tracing > 0:
#    1294             self._updatecounter += 1
#
# Terminator:

# %%
import random
import turtle


def isInScreen(w, t):
    if random.random() > 0.1:
        return True
    else:
        return False


t = turtle.Turtle()
wn = turtle.Screen()

t.shape('turtle')
while isInScreen(wn, t):
    coin = random.randrange(0, 2)
    if coin == 0:              # heads
        t.left(90)
    else:                      # tails
        t.right(90)

    t.forward(50)

wn.exitonclick()

# %%
# #lets get Stars

import turtle, random


star=turtle.Turtle()
star.speed(0)
star.hideturtle()
    
    
def draw_star(pos,color,length): 
    x,y= pos
    star.color(color)
    star.penup()
    star.goto(x,y)
    star.pendown()
    star.begin_fill()
    for i in range(5):
        star.forward(length)
        star.right(144)
        star.forward(length)
    star.end_fill()
    
    
    
# def random_length():
#     return(random.randint(5,25))

# while True:
#     color=random.choice(colors)
#     pos=random_pos()
#     length=random_length()

#     draw_star(pos,color,length)
#     write_text(color)
# while True:
#     color=random.choice(colors)
#     #turtle.goto(randint(-100,0),randint(0,100))
#     pos=random_pos()





turtle.exitonclick()
# Out:
# ---------------------------------------------------------------------------
# Terminator                                Traceback (most recent call last)
# <ipython-input-2-102f547fc181> in <module>
#       4
#       5
# ----> 6 star=turtle.Turtle()
#       7 star.speed(0)
#       8 star.hideturtle()
#
# ~\anaconda3\lib\turtle.py in __init__(self, shape, undobuffersize, visible)
#    3811         if Turtle._screen is None:
#    3812             Turtle._screen = Screen()
# -> 3813         RawTurtle.__init__(self, Turtle._screen,
#    3814                            shape=shape,
#    3815                            undobuffersize=undobuffersize,
#
# ~\anaconda3\lib\turtle.py in __init__(self, canvas, shape, undobuffersize, visible)
#    2555         self._undobuffersize = undobuffersize
#    2556         self.undobuffer = Tbuffer(undobuffersize)
# -> 2557         self._update()
#    2558
#    2559     def reset(self):
#
# ~\anaconda3\lib\turtle.py in _update(self)
#    2658             return
#    2659         elif screen._tracing == 1:
# -> 2660             self._update_data()
#    2661             self._drawturtle()
#    2662             screen._update()                  # TurtleScreenBase
#
# ~\anaconda3\lib\turtle.py in _update_data(self)
#    2644
#    2645     def _update_data(self):
# -> 2646         self.screen._incrementudc()
#    2647         if self.screen._updatecounter != 0:
#    2648             return
#
# ~\anaconda3\lib\turtle.py in _incrementudc(self)
#    1290         if not TurtleScreen._RUNNING:
#    1291             TurtleScreen._RUNNING = True
# -> 1292             raise Terminator
#    1293         if self._tracing > 0:
#    1294             self._updatecounter += 1
#
# Terminator:

# %%
import turtle
import random

colors = ['red', 'green', 'blue', 'yellow', 'cyan', 'pink', 'lime', 'orange', 'purple']


star=turtle.Turtle()
star.speed(0)
star.hideturtle()



def draw_star(pos,color,length): 
    x,y= pos
    star.color(color)
    star.penup()
    star.goto(x,y)
    star.pendown()
    star.begin_fill()
    for i in range(5):
        star.forward(length)
        star.right(144)
        star.forward(length)
    star.end_fill()
    
    
    
draw_star((100,100),'red',25)

def random_pos():
    return(random.randint(-390,390),random.randint(-200,290))

def random_length():
    return(random.randint(5,25))

while True:
    color=random.choice(colors)
    pos=random_pos()
    length=random_length()

    draw_star(pos,color,length)


turtle.exitonclick()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# <ipython-input-1-1dbb9923e62d> in <module>
#      39     length=random_length()
#      40
# ---> 41     draw_star(pos,color,length)
#      42
#      43
#
# <ipython-input-1-1dbb9923e62d> in draw_star(pos, color, length)
#      15     star.color(color)
#      16     star.penup()
# ---> 17     star.goto(x,y)
#      18     star.pendown()
#      19     star.begin_fill()
#
# ~\anaconda3\lib\turtle.py in goto(self, x, y)
#    1774             self._goto(Vec2D(*x))
#    1775         else:
# -> 1776             self._goto(Vec2D(x, y))
#    1777
#    1778     def home(self):
#
# ~\anaconda3\lib\turtle.py in _goto(self, end)
#    3156                       (self.currentLineItem,
#    3157                       self.currentLine[:],
# -> 3158                       screen._pointlist(self.currentLineItem),
#    3159                       self.items[:])
#    3160                       )
#
# ~\anaconda3\lib\turtle.py in _pointlist(self, item)
#     753         (9.9999999999999982, 0.0)]
#     754         >>> """
# --> 755         cl = self.cv.coords(item)
#     756         pl = [(cl[i], -cl[i+1]) for i in range(0, len(cl), 2)]
#     757         return  pl
#
# <string> in coords(self, *args, **kw)
#
# ~\anaconda3\lib\tkinter\__init__.py in coords(self, *args)
#    2759         return [self.tk.getdouble(x) for x in
#    2760                            self.tk.splitlist(
# -> 2761                    self.tk.call((self._w, 'coords') + args))]
#    2762
#    2763     def _create(self, itemType, args, kw): # Args: (val, val, ..., cnf={})
#
# TclError: invalid command name ".!canvas"

# %%
import turtle
turtle.mode('logo')
turtle.fillcolor('red')
turtle.begin_fill()
for i in range(5):
    turtle.circle(30,180)
    turtle.right(108)
turtle.end_fill()
turtle.up()
turtle.goto(-30,-40)
turtle.down()
turtle.color('yellow')
turtle.dot(40)
turtle.done()

# %%
import turtle, random

win=turtle.Screen()
win.setup(width=1200, height=750)
win.bgcolor('black')


flower = turtle.Turtle()
flower.speed(0)
flower.width(3)

colors = ['red', 'green', 'blue', 'yellow', 'cyan', 'pink', 'lime', 'orange', 'gray', 'silver', 'wheat', 'turquoise', 'navy']



def draw_flower(pos3, color, length3, length4):
    x,y = pos3
    #flower.mode(logo)
    flower.fillcolor(color)
    flower.penup()
    flower.goto(x,y)
    flower.pendown()
    flower.begin_fill()
    for i in range(5):
        flower.circle(length3, length4)
        flower.right(108)
    flower.end_fill()
    flower.penup()
    flower.goto(x,y)
    flower.pendown()
    flower.color(color)
    flower.dot(length3)
    
    
def random_pos3():
    return(random.randint(-390,390),random.randint(-200,290))

def random_length3():
    return(random.randint(1,11))

def random_length4():
    return(random.randint(21,111))





while True:
    color=random.choice(colors)
    pos3=random_pos3()
    length3=random_length3()
    length4=random_length4()

    draw_flower(pos3,color,length3, length4)

    
    
    

    
    
    
turtle.exitonclick()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# <ipython-input-1-86b011808bb1> in <module>
#      52     length4=random_length4()
#      53
# ---> 54     draw_flower(pos3,color,length3, length4)
#      55
#      56
#
# <ipython-input-1-86b011808bb1> in draw_flower(pos3, color, length3, length4)
#      18     #flower.mode(logo)
#      19     flower.fillcolor(color)
# ---> 20     flower.penup()
#      21     flower.goto(x,y)
#      22     flower.pendown()
#
# ~\anaconda3\lib\turtle.py in penup(self)
#    2105         if not self._drawing:
#    2106             return
# -> 2107         self.pen(pendown=False)
#    2108
#    2109     def pendown(self):
#
# ~\anaconda3\lib\turtle.py in pen(self, pen, **pendict)
#    2423                 newLine = True
#    2424         if newLine:
# -> 2425             self._newLine()
#    2426         if "pendown" in p:
#    2427             self._drawing = p["pendown"]
#
# ~\anaconda3\lib\turtle.py in _newLine(self, usePos)
#    3289             self.items.append(self.currentLineItem)
#    3290         else:
# -> 3291             self.screen._drawline(self.currentLineItem, top=True)
#    3292         self.currentLine = []
#    3293         if usePos:
#
# ~\anaconda3\lib\turtle.py in _drawline(self, lineitem, coordlist, fill, width, top)
#     549             self.cv.itemconfigure(lineitem, width=width)
#     550         if top:
# --> 551             self.cv.tag_raise(lineitem)
#     552
#     553     def _delete(self, item):
#
# <string> in tag_raise(self, *args, **kw)
#
# ~\anaconda3\lib\tkinter\__init__.py in tag_raise(self, *args)
#    2935         """Raise an item TAGORID given in ARGS
#    2936         (optional above another item)."""
# -> 2937         self.tk.call((self._w, 'raise') + args)
#    2938
#    2939     lift = tkraise = tag_raise
#
# TclError: invalid command name ".!canvas"
